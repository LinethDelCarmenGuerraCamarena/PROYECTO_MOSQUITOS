# %%
from pathlib import Path
from PIL import Image
import numpy as np

#rutas de carpetas
TIF_FOLDER = r"C:\Users\linet\Project\alas"        # .tif originales
JPG_FOLDER = r"C:\Users\linet\Project\jpg_images"        # .jpg convertidos
MASK_FOLDER = r"C:\Users\linet\Project\alas_png"         # máscaras .png
FOREGROUND_FOLDER = r"C:\Users\linet\Project\foregrounds"
BACKGROUND_FOLDER = r"C:\Users\linet\Project\backgrounds"

#crear carpetas si no existen
for folder in [JPG_FOLDER, FOREGROUND_FOLDER, BACKGROUND_FOLDER]:
    Path(folder).mkdir(parents=True, exist_ok=True)

#obtener listas de archivos y ordenar por nombre
tif_files = sorted(Path(TIF_FOLDER).glob("*.tif"))
mask_files = sorted(Path(MASK_FOLDER).glob("*.png"))

#verificar que haya la misma cantidad
assert len(tif_files) == len(mask_files), f"{len(tif_files)} TIFFs vs {len(mask_files)} masks"

#procesar cada imagen
for tif_file, mask_file in zip(tif_files, mask_files):
    #convertir .tif a .jpg
    img = Image.open(tif_file).convert("RGB")
    jpg_path = Path(JPG_FOLDER) / (tif_file.stem + ".jpg")
    img.save(jpg_path, "JPEG", quality=95)

    #cargar máscara
    mask = Image.open(mask_file).convert("L")  # grayscale
    mask_np = np.array(mask)
    mask_bin = (mask_np > 0).astype(np.uint8) * 255  # binaria

    #crear foreground con transparencia
    img_rgba = img.convert("RGBA")
    fg_np = np.array(img_rgba)
    fg_np[:, :, 3] = mask_bin  # canal alfa
    foreground = Image.fromarray(fg_np)
    foreground.save(Path(FOREGROUND_FOLDER) / (tif_file.stem + "_fg.png"))

    #crear background (opcional)
    bg_np = np.array(img_rgba)
    bg_np[:, :, 3] = 255 - mask_bin
    background = Image.fromarray(bg_np)
    background.save(Path(BACKGROUND_FOLDER) / (tif_file.stem + "_bg.png"))

    print(f"Processed {tif_file.stem}")
# Out:
# Processed 06274Q-2-A
# Processed 06274Q-3-A
# Processed 10m19cp-A
# Processed 11m19cp-A
# Processed 1208QR-10-A
# Processed 1208QR-7A
# Processed 1208QR-8A
# Processed 1209QR-1-A
# Processed 1235QR-21A
# Processed 12m19cp-A
# Processed 13m19cp-A
# Processed 140317Q1-A
# Processed 140317Q2-A
# Processed 140517Q1-A
# Processed 140517Q2-A
# Processed 1408X-1A
# Processed 14233-1-A
# Processed 14233-2-A
# Processed 14234Q-5-A
# Processed 14236-2-A
# Processed 14236-4-A
# Processed 14236-5-A
# Processed 14237-1-A
# Processed 1423QR-2-A
# Processed 1423QR-3-A
# Processed 1423QR-5-A
# Processed 1423QR-6-A
# Processed 1423QR-7-A
# Processed 1423QR-8-A
# Processed 1423QR-9-A
# Processed 14m19cp-A
# Processed 151212M1-A
# Processed 15m19cp-A
# Processed 16195-1A
# Processed 16195-2A
# Processed 16m19cp-A
# Processed 18m19cp-A
# Processed 19468-1-A
# Processed 19468-2-A
# Processed 1946QR-1-A
# Processed 1946QR-2-A
# Processed 1946QR-3-A
# Processed 1946QR-4-A
# Processed 1946QR-5-A
# Processed 1946QR-6-A
# Processed 19m19cp-A
# Processed 1m19cp-A
# Processed 21m19cp-A
# Processed 230980-1A
# Processed 230980-3A
# Processed 23m19cp-A
# Processed 240810M-1A
# Processed 240810M-2A
# Processed 24m19cp-A
# Processed 252931-A
# Processed 25m19cp-A
# Processed 260709-1A
# Processed 260709-2A
# Processed 260709-3A
# Processed 26m19cp-A
# Processed 27m19cp-A
# Processed 28m19cp-A
# Processed 2m19cp-A
# Processed 30m19cp-A
# Processed 31m19cp-A
# Processed 32m19cp-A
# Processed 33m19cp-A
# Processed 34m19cp-A
# Processed 35m19cp-A
# Processed 36m19cp-A
# Processed 38m19cp-A
# Processed 39m19cp-A
# Processed 3m19cp-A
# Processed 40m19cp-A
# Processed 42m19cp-A
# Processed 43m19cp-A
# Processed 46m19cp-A
# Processed 4905-1A
# Processed 4905-2A
# Processed 4m19cp-A
# Processed 50918Q-1A
# Processed 5918-2a
# Processed 5918-3A
# Processed 5m19cp-A
# Processed 6264-1-A
# Processed 6264-2-A
# Processed 6264-3-A
# Processed 6265Q-3-A
# Processed 6265Q-4-A
# Processed 6265Q-5-A
# Processed 6265Q-6-A
# Processed 6265Q7-A
# Processed 6m19cp-A
# Processed 6UA-109-2-A
# Processed 702QR-4-A
# Processed 702QR-5-A
# Processed 70622-1-A
# Processed 70622-10-A
# Processed 70622-2-A
# Processed 70622-3-A
# Processed 70622-4-A
# Processed 70622-5-A
# Processed 70622-6-A
# Processed 70622-7-A
# Processed 70622-8-A
# Processed 70622-9-A
# Processed 70822-1-A
# Processed 70822-3-A
# Processed 70822-4-A
# Processed 70822-5-A
# Processed 70822-6-A
# Processed 70822-7-A
# Processed 70822-8-A
# Processed 70822-9-A
# Processed 7m19cp-A
# Processed 8899-1A
# Processed 8m19cp-A
# Processed 9m19cp-A
# Processed BAC84-1-A
# Processed BAC84-2-A
# Processed BAC84-3-A
# Processed BAC85-3-A
# Processed BAC85-4-A
# Processed BlacQ-1A
# Processed BlacQ-2A
# Processed BlacQ-3A
# Processed BlacQ-4A
# Processed BlacQ-6A
# Processed BlacQ-7A
# Processed BlacQ-8A
# Processed BlacQ-9A
# Processed Cua10-1A
# Processed DZ18-1A
# Processed FCPD18-1-A
# Processed FCPD18-2-A
# Processed GUA-109-3-A
# Processed IX99-1-A
# Processed IX99-2-A
# Processed IxhuV-1A
# Processed LOX98-2-A
# Processed LOX98-3-A
# Processed LOX98-4-A
# Processed LOX98-5-A
# Processed LV17-1A
# Processed LV17-2A
# Processed LV17-4-A
# Processed Mac6Q-2A
# Processed MacQ-1A
# Processed Mor09-1A
# Processed Naxa-2A
# Processed Naxa-3A
# Processed Naxa-4A
# Processed NAY6573-1-A
# Processed NAY6573-12-A
# Processed NAY6573-13-A
# Processed NAY6573-15-A
# Processed NAY6573-18-A
# Processed NAY6573-19-A
# Processed NAY6573-21-A
# Processed NAY6573-3-A
# Processed NAY6573-4-A
# Processed NAY6573-7-A
# Processed NAY98-15-A
# Processed NAY98-17-A
# Processed NAY98-18-A
# Processed NAY98-20-A
# Processed NAY98-21-A
# Processed NAY98-22-A
# Processed NAY98-3-A
# Processed NAY98-5-A
# Processed NAY98-8-A
# Processed NAY98-9-A
# Processed NayXT-2A
# Processed NayXT-4A
# Processed NayXT-5A
# Processed NayXT-6A
# Processed NayXT-7A
# Processed NicQ-1A
# Processed NicQ-2A
# Processed NicQ-3A
# Processed NicQ-4A
# Processed NicQ-5A
# Processed NicQ-6A
# Processed NicQ-7a1
# Processed OAX531C-3-A
# Processed Oax60-2-M-A
# Processed Oax60-3-H-A
# Processed Oax60-4-H-A
# Processed Oax60-5-M-A
# Processed Oax60-6-M-A
# Processed Oax61-1-X-A
# Processed Oax62-1-M-A
# Processed Oax62-2-H-A
# Processed Oax62-3-M-A
# Processed Oax62-5-M-A
# Processed Oax62-8-M-A
# Processed Oax63-1-x-A
# Processed Oax63-2-x-A
# Processed Oax63-4-x-A
# Processed Oax64-1-M-A
# Processed Oax64-2-M-A
# Processed Oax65-1-H-A
# Processed Oax65-3-H-A
# Processed Oax65-4-H-A
# Processed Oax66-1-H-A
# Processed Oax66-2-M-A
# Processed Oax66-3-M-A
# Processed Oax66-4-H-A
# Processed Oax66-5-M-A
# Processed Oax66-6-M-A
# Processed Oax67-1-X-A
# Processed Oax68-1-H-A
# Processed Oax68-2-H-A
# Processed Oax68-3-H-A
# Processed Oax68-4-H-A
# Processed Oax68-5-M-A
# Processed Oax68-6-H-A
# Processed Oax68-7-H-A
# Processed Oax68-8-H-A
# Processed Oax68-9-H-A
# Processed Oax69-1-X-A
# Processed Oax69-2-X-A
# Processed Oax70-1-X-A
# Processed Oax71-1-M-A
# Processed Oax71-2-H-A
# Processed Oax71-3-M-A
# Processed Oax71-4-M-A
# Processed Oax71-6-H-A
# Processed Oax71-7-M-A
# Processed Oax71-8-H-A
# Processed Oax72-1-X-A
# Processed Oax72-2-X-A
# Processed OAXC531-1-A
# Processed OAXC531-10-A
# Processed OAXC531-11-A
# Processed OAXC531-13-A
# Processed OAXC531-14-A
# Processed OAXC531-17-A
# Processed OAXC531-18-A
# Processed OAXC531-2-A
# Processed OAXC531-29-A
# Processed OAXC531-30-A
# Processed OAXC531-35-A
# Processed OAXC531-4-A
# Processed OAXC531-5-A
# Processed OAXC531-6-A
# Processed OAXC531-7-A
# Processed OAXC531-9-A
# Processed OAXCH8-1-A
# Processed OAXCH8-2-A
# Processed OAXCH8-7-A
# Processed OAXCH8-8-A
# Processed OAXLV-1-A
# Processed OaxSJ-1A
# Processed OaxSJ-2A
# Processed PB104-1-A
# Processed PB104-2-A
# Processed PB104-4-A
# Processed PB97-1-A
# Processed PB97-2-A
# Processed PB97-3-A
# Processed PM103-1-A
# Processed PM103-2-A
# Processed PM103-3-A
# Processed PM103-5-A
# Processed PM103-7-A
# Processed QR1417-1A
# Processed QR21-1A
# Processed QR21-2A
# Processed QR21-3A
# Processed QR21-4A
# Processed QR21-5A
# Processed QR6721-A
# Processed QR6760-3-A
# Processed QRSOL-1-A
# Processed QRSOL-2-A
# Processed QRSOL-3-A
# Processed QUET99-1-A
# Processed QUET99-2-A
# Processed SilQ-1A
# Processed SilQ-2A
# Processed SilQ-3A
# Processed SilQ-4A
# Processed SilQ-5A
# Processed SilQ-6A
# Processed SilQ-7A
# Processed SolfQ-3A
# Processed SolfQ-4A
# Processed SolfQ-5A
# Processed SolfQ-8A
# Processed SolfQ-9A
# Processed Tab00-2A
# Processed Tab00-4A
# Processed Tab00-5A
# Processed TAB03-1-A
# Processed TAB03-2-A
# Processed VER99-2-A
# Processed VER99-3-A
